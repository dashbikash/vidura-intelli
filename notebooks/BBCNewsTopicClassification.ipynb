# %% [markdown]
# <a href="https://colab.research.google.com/github/dashbikash/vidura-intelli/blob/main/notebooks/BBCNewsTopicClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df_train=pd.read_csv('https://github.com/dashbikash/vidura-intelli/raw/main/datasets/bbc-news/BBC%20News%20Train.csv')
df_test=pd.read_csv('https://github.com/dashbikash/vidura-intelli/raw/main/datasets/bbc-news/BBC%20News%20Test.csv')

# %%
df_train.head()
# Out:
#    ArticleId                                               Text  Category
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business

# %%
df_train.isna().sum()
# Out:
# ArticleId    0
# Text         0
# Category     0
# dtype: int64

# %%
df_train.groupby("Category").count()
# Out:
#                ArticleId  Text
# Category
# business             336   336
# entertainment        273   273
# politics             274   274
# sport                346   346
# tech                 261   261

# %%
sns.histplot(df_train,x="Category")
# Out:
# <Axes: xlabel='Category', ylabel='Count'>

# %%
import nltk
nltk.download('punkt')
from textblob import TextBlob

def clean_text(text):
    blob=TextBlob(text.lower())
    return blob.words

def sentiment_polarity(text):
    blob=TextBlob(text.lower())
    return blob.sentiment[0]


df_train["CleanText"]=df_train["Text"].apply(clean_text)
df_train["Polarity"]=df_train["Text"].apply(sentiment_polarity)
df_train.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    ArticleId                                               Text  Category  \
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business
#
#                                            CleanText  Polarity
# 0  [worldcom, ex-boss, launches, defence, lawyers...  0.023320
# 1  [german, business, confidence, slides, german,...  0.077917
# 2  [bbc, poll, indicates, economic, gloom, citize...  0.077754
# 3  [lifestyle, governs, mobile, choice, faster, b...  0.156109
# 4  [enron, bosses, in, 168m, payout, eighteen, fo...  0.009685

# %%
# Out:
#    ArticleId                                               Text  Category  \
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business
#
#     CleanText
# 0  clean text
# 1  clean text
# 2  clean text
# 3  clean text
# 4  clean text
